# %% [markdown]
# <a href="https://colab.research.google.com/github/Garden1107/Cpp-Self-study/blob/main/AI4%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
a = pd.read_excel('연도별출생인구.xlsx')     #pd.으로해야 데이터를 읽을 수 있음.

# %%
a
# Out:
#       연도    출생아수  천명당출생률
# 0   1951  728175    37.7
# 1   1952  775630    39.6
# 2   1953  830330    41.6
# 3   1954  892236    43.4
# 4   1955  961055    45.4
# ..   ...     ...     ...
# 63  2014  435435     8.6
# 64  2015  438420     8.6
# 65  2016  406243     7.9
# 66  2017  357771     7.0
# 67  2018  326900     6.4
#
# [68 rows x 3 columns]

# %%
a.head()        #함수 헤드, 변수들이 갖고 있는 상단에 있는 대가리 4개 확인용 함수. 컴퓨터에서 첫번째는 0번부터.
# Out:
#      연도    출생아수  천명당출생률
# 0  1951  728175    37.7
# 1  1952  775630    39.6
# 2  1953  830330    41.6
# 3  1954  892236    43.4
# 4  1955  961055    45.4

# %%
#헤더, 표의 제일 최상단, 제목이 들어있는것을 말함. 항상 데이터에 존재함.

# %%
a[0:2]           #a안에 있는 5번째 데이터 2에서 마무리 짓기 때문에 0하고 2만 나옴.
# Out:
#      연도    출생아수  천명당출생률
# 0  1951  728175    37.7
# 1  1952  775630    39.6

# %%
# 변수명['열이름']  [행번호]    #열을 보고 싶으면 .쓰고 열이름/ 행을 보고싶으면 변수명[]만 쓰면 됨. //열행 둘다 잘라낼때쓰는거임.

# %%
a['출생아수']               #이거 아래거 둘다 똑같지만 이걸 ㅊㅊ. 공백이 들어가 있는 경우가 있을땐 아래걸 못씀.
# Out:
# 0     728175
# 1     775630
# 2     830330
# 3     892236
# 4     961055
#        ...
# 63    435435
# 64    438420
# 65    406243
# 66    357771
# 67    326900
# Name: 출생아수, Length: 68, dtype: int64

# %%
a.출생아수
# Out:
# 0     728175
# 1     775630
# 2     830330
# 3     892236
# 4     961055
#        ...
# 63    435435
# 64    438420
# 65    406243
# 66    357771
# 67    326900
# Name: 출생아수, Length: 68, dtype: int64

# %%
a['출생아수'][1:3]          #만약에 몇개의 데이터가 나옵니까?? 물어볼경우 2개가 답임.
# Out:
# 1    775630
# 2    830330
# Name: 출생아수, dtype: int64

# %%
b = a['출생아수'][1:3]  #마찬가지로 변수에 저장해서 씀.

# %%
pd.read_excel('상도동 아파트 실거래가.xlsx', header = [16])     #변수 이름에는 . 이 못들어감. _언더바만 ㄱㄴ.
#[]대괄호 인덱스 번호 0번부터 시작하기 때문에 우리눈으로 볼때에는 17번이지만 16번행으로 지정해줘야함.
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                시군구   번지   본번  부번             단지명   전용면적(㎡)    계약년월  계약일  \
# 0    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   59.7827  202301    7
# 1    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202301   11
# 2    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202301   18
# 3    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   59.7827  202302    8
# 4    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   59.7827  202302   24
# ..             ...  ...  ...  ..             ...       ...     ...  ...
# 206  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202303   12
# 207  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202303   23
# 208  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202304    1
# ...

# %%
a = pd.read_excel('상도동 아파트 실거래가.xlsx', header = [16])
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
a
# Out:
#                시군구   번지   본번  부번             단지명   전용면적(㎡)    계약년월  계약일  \
# 0    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   59.7827  202301    7
# 1    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202301   11
# 2    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202301   18
# 3    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   59.7827  202302    8
# 4    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   59.7827  202302   24
# ..             ...  ...  ...  ..             ...       ...     ...  ...
# 206  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202303   12
# 207  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202303   23
# 208  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202304    1
# 209  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.8840  202306   16
# 210  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지  120.9360  202306   24
#
#            거래금액(만원)   층  건축년도        도로명     해제사유발생일  거래유형  중개사소재지
# ...

# %%
a.drop(index=[0,2,4], axis=0)      #0번2번4번 날라간 걸 보여줌.
# Out:
#                시군구   번지   본번  부번             단지명   전용면적(㎡)    계약년월  계약일  \
# 1    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202301   11
# 3    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   59.7827  202302    8
# 5    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.8746  202303    6
# 6    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   59.5905  202303   11
# 7    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202303   11
# ..             ...  ...  ...  ..             ...       ...     ...  ...
# 206  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202303   12
# 207  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202303   23
# 208  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202304    1
# 209  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.8840  202306   16
# 210  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지  120.9360  202306   24
#
#            거래금액(만원)   층  건축년도        도로명     해제사유발생일  거래유형  중개사소재지
# ...

# %%
a.drop(index=[0,2,4], axis=0)              #a변수에 있는 값을 버리는 함수 드롭 0번2번4번을  보여주는 값이
v =   a.drop(index=[0,2,4], axis=0)     #0번2번4번을 지운값을 v변수에 저장하는 코드이다.
        ###이거 차이점 시험에 무조건 낼거임!!!!! 변형해서.

# %%
a.drop(index=[0,2,4], axis=0)
a.drop(a.index[0:17], axis=0)      #0번째부터 16번째까지(범위) 날려버리는데 한번더 확인해이런 느낌.  a.한번 더써줘야함.!!! 확인용.
# Out:
#                시군구   번지   본번  부번             단지명   전용면적(㎡)    계약년월  계약일  \
# 17   서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202306   13
# 18   서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202306   14
# 19   서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202306   21
# 20   서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202306   30
# 21   서울특별시 동작구 상도동  414  414   0              건영   32.8000  202209   30
# ..             ...  ...  ...  ..             ...       ...     ...  ...
# 206  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202303   12
# 207  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202303   23
# 208  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202304    1
# 209  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.8840  202306   16
# 210  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지  120.9360  202306   24
#
#            거래금액(만원)   층  건축년도        도로명  해제사유발생일  거래유형          중개사소재지
# ...

# %%
a.drop(a.index[0:17], axis=0 , inplace=True)   #지금 17부터임.

# %%
a
# Out:
#                시군구   번지   본번  부번             단지명   전용면적(㎡)    계약년월  계약일  \
# 17   서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202306   13
# 18   서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202306   14
# 19   서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202306   21
# 20   서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202306   30
# 21   서울특별시 동작구 상도동  414  414   0              건영   32.8000  202209   30
# ..             ...  ...  ...  ..             ...       ...     ...  ...
# 206  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202303   12
# 207  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202303   23
# 208  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202304    1
# 209  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.8840  202306   16
# 210  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지  120.9360  202306   24
#
#            거래금액(만원)   층  건축년도        도로명  해제사유발생일  거래유형          중개사소재지
# ...

# %%
a.drop(columns=['번지'], axis=1, inplace=True)

# %%
a
# Out:
#                시군구   본번  부번             단지명   전용면적(㎡)    계약년월  계약일  \
# 17   서울특별시 동작구 상도동  903   0     e편한세상상도노빌리티   84.9704  202306   13
# 18   서울특별시 동작구 상도동  903   0     e편한세상상도노빌리티   84.9704  202306   14
# 19   서울특별시 동작구 상도동  903   0     e편한세상상도노빌리티   84.9704  202306   21
# 20   서울특별시 동작구 상도동  903   0     e편한세상상도노빌리티   84.9704  202306   30
# 21   서울특별시 동작구 상도동  414   0              건영   32.8000  202209   30
# ..             ...  ...  ..             ...       ...     ...  ...
# 206  서울특별시 동작구 상도동  533   0  힐스테이트 상도 프레스티지   84.9510  202303   12
# 207  서울특별시 동작구 상도동  533   0  힐스테이트 상도 프레스티지   84.9510  202303   23
# 208  서울특별시 동작구 상도동  533   0  힐스테이트 상도 프레스티지   84.9510  202304    1
# 209  서울특별시 동작구 상도동  533   0  힐스테이트 상도 프레스티지   84.8840  202306   16
# 210  서울특별시 동작구 상도동  533   0  힐스테이트 상도 프레스티지  120.9360  202306   24
#
#            거래금액(만원)   층  건축년도        도로명  해제사유발생일  거래유형          중개사소재지
# 17          140,000   6  2018      만양로 6      NaN  중개거래          서울 동작구
# ...
